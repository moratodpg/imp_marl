# %%
import os
import glob

sacred_dir = "logs"
parent_dir = os.getcwd()
print(os.getcwd())
test_json_files = glob.glob(os.path.join(parent_dir, sacred_dir, "**/test**/*info.json"), recursive=True)
print(len(test_json_files))

# %%
dict_heuristic={'heuristics_10_9uc_ref_2023_04_15_130930.npz': -63.702031546300006,
 'heuristics_5_4uc_camp_2023_04_15_130400.npz': -28.56832624025458,
 'heuristics_10_9uc_camp_2023_04_15_130400.npz': -64.54566487487939,
 'heuristics_3_2c_camp_2023_04_15_130700.npz': -15.244287768169668,
 'heuristics_100_95uc_camp_2023_04_15_130330.npz': -231.51831502811925,
 'heuristics_3_2uc_ref_2023_04_15_130930.npz': -12.548031501250763,
 'heuristics_100_95c_camp_2023_04_15_130630.npz': -194.00829458241884,
 'heuristics_5_4uc_ref_2023_04_15_130930.npz': -25.16981083470593,
 'heuristics_50_48c_ref_2023_04_15_130801.npz': -239.99827314977028,
 'heuristics_50_48c_camp_2023_04_15_130630.npz': -211.0397273727547,
 'heuristics_50_48uc_camp_2023_04_15_130330.npz': -232.66864066644195,
 'heuristics_5_4c_ref_2023_04_15_130801.npz': -28.089348983294887,
 'heuristics_100_95uc_ref_2023_04_15_130930.npz': -262.437213500905,
 'heuristics_5_4c_camp_2023_04_15_130630.npz': -30.46859501673695,
 'heuristics_3_2uc_camp_2023_04_15_130400.npz': -15.096777503160995,
 'heuristics_10_9c_camp_2023_04_15_130630.npz': -68.45376456917336,
 'heuristics_3_2c_ref_2023_04_15_130801.npz': -12.997522667776952,
 'heuristics_10_9c_ref_2023_04_15_130801.npz': -67.70872642438087,
 'heuristics_100_95c_ref_2023_04_15_130801.npz': -218.08651217477365,
 'heuristics_50_48uc_ref_2023_04_15_130930.npz': -268.06588862167297,
 'heuristics_owf_2_3camp_2023_04_15_130030.npz': -115.20353634573738,
 'heuristics_owf_1_3ref_2023_04_15_131101.npz': -58.30502638737299,
 'heuristics_owf_25_3camp_2023_04_15_125129.npz': -1248.1854220407279,
 'heuristics_owf_5_3ref_2023_04_15_131101.npz': -292.2865772354046,
 'heuristics_owf_2_3ref_2023_04_15_131101.npz': -116.91581627560167,
 'heuristics_owf_5_3camp_2023_04_15_125159.npz': -267.2232210135788,
 'heuristics_owf_50_3camp_2023_04_15_125029.npz': -2436.2737196188314,
 'heuristics_owf_50_3ref_2023_04_15_131100.npz': -2925.0128544559384,
 'heuristics_owf_1_3camp_2023_04_15_125559.npz': -62.15511188227698,
 'heuristics_owf_25_3ref_2023_04_15_131101.npz': -1463.7829664424578}

heuristic_results_cc_False = {
    # uc ref
    "uc_3":  -12.548031501250763,
    "uc_5":  -25.16981083470593,
    "uc_10": -63.702031546300006,
    "uc_50": -268.06588862167297,
    "uc_100": -262.437213500905,
    # c ref
    "c_3": -12.997522667776952,
    "c_5": -28.089348983294887,
    "c_10": -67.70872642438087,
    "c_50": -239.99827314977028,
    "c_100": -218.08651217477365,
    # owf ref
    "owf_1": -58.30502638737299,
    "owf_2": -116.91581627560167,
    "owf_5": -292.2865772354046,
    "owf_25": -1463.7829664424578,
    "owf_50": -2925.0128544559384
}
heuristic_results_cc_True = {
    # uc camp
    "uc_3": -15.096777503160995,
    "uc_5": -28.56832624025458,
    "uc_10": -64.54566487487939,
    "uc_50": -232.66864066644195,
    "uc_100": -231.51831502811925,
    # c camp
    "c_3": -15.244287768169668,
    "c_5": -30.46859501673695,
    "c_10": -68.45376456917336,
    "c_50": -211.0397273727547,
    "c_100": -194.00829458241884,
    # owf camp
    "owf_1": -62.15511188227698,
    "owf_2": -115.20353634573738,
    "owf_5": -267.2232210135788,
    "owf_25": -1248.1854220407279,
    "owf_50": -2436.2737196188314
}

# Compare dict_heuristic and heuristic_results_cc_False
# To do so, start with heuristic_results_cc_False and, for each VALUE, print the key in heuristic_results_cc_False and the key that has this value in dict_heuristic
for key, value in heuristic_results_cc_False.items():
    for key2, value2 in dict_heuristic.items():
        if value == value2:
            print(key, key2)
print("  ")
for key, value in heuristic_results_cc_True.items():
    for key2, value2 in dict_heuristic.items():
        if value == value2:
            print(key, key2)

# %%
import json

def exp_name_from_file(file):
    # test_10000_qvmix_uc_50_owf_25_9__2023-03-15_23-09-01__2023-03-21_06-07-53
    # test_10000_qvmix_uc_50_owf_25_cc_True_5__2023-04-01_23-05-55__2023-04-10_17-30-24
    exp_name = os.path.basename(os.path.dirname(file))
    exp_name = exp_name.split("_")[2:]

    if 'owf' in exp_name and 'dqn' in exp_name:
        index_env = 5
    elif "owf" in exp_name:
        index_env = 4
    else:
        index_env = 5

    if exp_name[index_env] != exp_name[2] and index_env is not 4:
        if int(exp_name[2]) == 10 and int(exp_name[index_env]) < 10:
            pass
        else:
            if not "dqn" in exp_name:
                print("merde")
                print(int(exp_name[2]) == 10, int(exp_name[index_env]) < 10)
                print(exp_name, exp_name[2], exp_name[index_env])
    if "cc_True" in file:
        exp_name = [exp_name[0], exp_name[index_env-1], exp_name[index_env], "cc_True"]
    else:
        exp_name = [exp_name[0], exp_name[index_env-1], exp_name[index_env], "cc_False"]
    if exp_name[1] == "sarl":
        exp_name[1]= "owf"
    return exp_name

def dict_results_from_json(test_json_files, method, env1, env2, cc):
    dict_all=[]

    for i in test_json_files:
        exp_name=exp_name_from_file(i)

        if cc and "cc_True" in i:
            pass
        elif not cc and ("cc_False" in i or "cc" not in i):
            pass
        else:
            continue

        if exp_name[0] == method and exp_name[1] == env1 and exp_name[2] == env2:
            exp_name = "_".join(exp_name)

            # Remove dqn too much
            if exp_name.startswith("dqn"):
                # ignore uc/ic 10 50 100 and owf 5 25 50
                if "10" in k or "50" in k or "100" in k or ("owf" in k and ('5' in k or '25' in k or '50' in k)):
                    continue
        else:
            continue
        try:
            with open(i, "r") as file:
                infos = json.load(file)
                dict_exp= {}
                dict_exp["name"] = os.path.basename(os.path.dirname(i))
                dict_exp["test_return_mean"] = [i["value"] for i in infos["test_return_mean"]]
                dict_exp["test_return_mean_T"] = infos["test_return_mean_T"]
                dict_all.append(dict_exp)
        except Exception as e:
            print("Exception",i, e)
    return dict_all

methods = ["qmix", "qvmix",  "coma", "iql", "qplex", "dqn", "facmac"]
env1 = ["uc", "c", "owf"]
env2 = {"uc":["3", "5", "10", "50", "100" ], "c":["3", "5", "10", "50", "100"], "owf":["1","2","5","25","50"]}
cc = [True, False]
results={}
for cc_ in cc:
    for i in methods:
        for j in env1:
            for k in env2[j]:
                exp_name = f"{i}_{j}_{k}_cc_{cc_}"
                results[exp_name] = dict_results_from_json(test_json_files, i,j,k, cc_)

for k, v in results.items():
    print(k, len(v))

# %% [markdown]
# # DO NOT FORGET TO SET cc_str = "cc_False" or "cc_True"

# %%
cc_str = "cc_False"
if cc_str == "cc_True":
    heuristicsss = heuristic_results_cc_True
else:
    heuristicsss = heuristic_results_cc_False

# %%
from matplotlib.ticker import ScalarFormatter
from scipy.ndimage import gaussian_filter1d
import numpy as np
from matplotlib import pyplot as plt

def plot_function(list_of_exp, name="", ax=None, color=None, plot_y=True, plot_x=True, y_lim=None):
    list_1=[]
    for exp in list_of_exp:
        list_1.append(exp["test_return_mean"][:101])
    if len(list_1) != 10:
        print("Not 10 runs", name)
    np_ = np.array(list_1)
    mean = np.mean(np_, axis=0)
    std = np.std(np_, axis=0)
    median = np.median(np_, axis=0)
    perc_25 = np.percentile(np_, 25, axis=0)
    perc_75 = np.percentile(np_, 75, axis=0)
    sigma_std = 1.5
    time_steps = [i*25000 for i in range(mean.shape[0])]

    ax.plot(time_steps, gaussian_filter1d(median, sigma=1.5), lw=5, label=name, color=color)
    ax.fill_between(time_steps, gaussian_filter1d(perc_75,sigma=sigma_std), gaussian_filter1d(perc_25,sigma=sigma_std), facecolor=color, alpha=0.1)
    ax.set_xlim(0, 2000000)
    if y_lim:
        ax.set_ylim(y_lim[0], y_lim[1])

    if plot_y:
        fig.canvas.draw()
        ax.set_ylabel('Reward', fontsize=80)
        ax.yaxis.set_tick_params(length=15, width=5)
    else:
        # ticks_list=[item for item in ax.get_yticklabels()]
        # ax.set_yticks(ax.get_yticks()) # to remove a warning
        # ax.yaxis.set_ticklabels(["" for _ in ticks_list])
        ax.yaxis.set_tick_params(length=15, width=5)

    ax.xaxis.set_tick_params(length=15, width=5)
    fig.canvas.draw()
    a = ax.get_xticks()
    ax.set_xticks(np.arange(min(a), max(a)+1, 0.5*1000000))
    ax.set_xticks(ax.get_xticks()) # to remove a warning
    ax.set_xticklabels(['0', '0.5', '1', '1.5', '2'], fontsize=80)

    return mean,time_steps, ax

# %%
plt.style.use('seaborn-white')
fig, axes = plt.subplots(1,3)
fig.set_figheight(20)
fig.set_figwidth(120)
plt.subplots_adjust(wspace=0.17)
env1= "uc"
env2 = "3"
ax_index=0
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="QMIX",      ax=axes[ax_index], color="blue"    , y_lim=[-60,0])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="QVMix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="QPLEX",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="COMA",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="FACMAC",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="IQL",        ax=axes[ax_index], color="orange")
plot_function(results[f"dqn_{env1}_{env2}_{cc_str}"], name="DQN",        ax=axes[ax_index], color="black")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic1 = heuristicsss[f"{env1}_{env2}"]
env1= "c"
env2 = "3"
ax_index=1
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"  , y_lim=[-60,0])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
plot_function(results[f"dqn_{env1}_{env2}_{cc_str}"], name="dqn",        ax=axes[ax_index], color="black")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic2 = heuristicsss[f"{env1}_{env2}"]
env1= "owf"
env2 = "1"
ax_index=2
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"    , y_lim=[-150,0])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
plot_function(results[f"dqn_{env1}_{env2}_{cc_str}"], name="dqn",        ax=axes[ax_index], color="black")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic3 = heuristicsss[f"{env1}_{env2}"]

print(heuristic1, heuristic2, heuristic3)
axes[0].axhline(heuristic1, color="brown", linestyle="--", lw=5, label="Heuristic")
axes[1].axhline(heuristic2, color="brown", linestyle="--",  lw=5, label="Heuristic")
axes[2].axhline(heuristic3, color="brown", linestyle="--", lw=5, label="Heuristic")

for ax in axes:
    ax.grid()
plt.rc('font', size=80)
axes[1].set_xlabel('Timesteps ('+r'$\times \mathregular{10^{6}}$' + ')', fontsize=80)

handles, labels = axes[0].get_legend_handles_labels()

axbox = axes[1].get_position()
legend = fig.legend(handles, labels, bbox_to_anchor=[0.012, axbox.y0+.365,1,1], loc="center", ncol=10, prop={'size': 80})
for line, text in zip(legend.get_lines(), legend.get_texts()):
    text.set_color(line.get_color())
    line.set_linewidth(10)
import pickle
pickle.dump(legend, open("legend", "wb"))

plt.plot()
plt.savefig(f"sacred_scripts/plots/all_3_{cc_str}.pdf", bbox_inches='tight')
print("")

# %%
plt.style.use('seaborn-white')
fig, axes = plt.subplots(1,3)
fig.set_figheight(20)
fig.set_figwidth(120)
plt.subplots_adjust(wspace=0.17)

env1= "uc"
env2 = "5"
ax_index=0
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"    , y_lim=[-150,0])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
plot_function(results[f"dqn_{env1}_{env2}_{cc_str}"], name="dqn",        ax=axes[ax_index], color="black")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic1 = heuristicsss[f"{env1}_{env2}"]

env1= "c"
env2 = "5"
ax_index=1
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"  , y_lim=[-150,0])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
plot_function(results[f"dqn_{env1}_{env2}_{cc_str}"], name="dqn",        ax=axes[ax_index], color="black")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic2 = heuristicsss[f"{env1}_{env2}"]

env1= "owf"
env2 = "2"
ax_index=2
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"    , y_lim=[-300,0])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
plot_function(results[f"dqn_{env1}_{env2}_{cc_str}"], name="dqn",        ax=axes[ax_index], color="black")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic3 = heuristicsss[f"{env1}_{env2}"]

print(heuristic1, heuristic2, heuristic3)
axes[0].axhline(heuristic1, color="brown", linestyle="--", lw=5, label="Heuristic")
axes[1].axhline(heuristic2, color="brown", linestyle="--",  lw=5, label="Heuristic")
axes[2].axhline(heuristic3, color="brown", linestyle="--", lw=5, label="Heuristic")

for ax in axes:
    ax.grid()
plt.rc('font', size=80)
axes[1].set_xlabel('Timesteps ('+r'$\times \mathregular{10^{6}}$' + ')', fontsize=80)

plt.plot()
plt.savefig(f"sacred_scripts/plots/all_5_{cc_str}.pdf", bbox_inches='tight')
print("")

# %%
plt.style.use('seaborn-white')
fig, axes = plt.subplots(1,3)
fig.set_figheight(20)
fig.set_figwidth(120)
plt.subplots_adjust(wspace=0.17)

env1= "uc"
env2 = "10"
ax_index=0
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"    , y_lim=[-450,-25])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic1 = heuristicsss[f"{env1}_{env2}"]

env1= "c"
env2 = "10"
ax_index=1
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue", y_lim=[-450,-25])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic2 = heuristicsss[f"{env1}_{env2}"]

env1= "owf"
env2 = "5"
ax_index=2
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue", y_lim=[-600,-25])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green", )
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red", )
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan", )
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet", )
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange", )
#axes[ax_index].set_title(env1+"_"+env2)
for ax in axes:
    ax.grid()
plt.rc('font', size=80)
axes[1].set_xlabel('Timesteps ('+r'$\times \mathregular{10^{6}}$' + ')', fontsize=80)
heuristic3 = heuristicsss[f"{env1}_{env2}"]

print(heuristic1, heuristic2, heuristic3)
axes[0].axhline(heuristic1, color="brown", linestyle="--", lw=5, label="Heuristic")
axes[1].axhline(heuristic2, color="brown", linestyle="--",  lw=5, label="Heuristic")
axes[2].axhline(heuristic3, color="brown", linestyle="--", lw=5, label="Heuristic")


plt.plot()
plt.savefig(f"sacred_scripts/plots/all_10_{cc_str}.pdf", bbox_inches='tight')
print("")

# %%
plt.style.use('seaborn-white')
fig, axes = plt.subplots(1,3)
fig.set_figheight(20)
fig.set_figwidth(120)
plt.subplots_adjust(wspace=0.17)

env1= "uc"
env2 = "50"
ax_index=0
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"    , y_lim=[-2200,-150])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic1= heuristicsss[f"{env1}_{env2}"]

env1= "c"
env2 = "50"
ax_index=1
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"  , y_lim=[-2200,-150])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic2 = heuristicsss[f"{env1}_{env2}"]

env1= "owf"
env2 = "25"
ax_index=2
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue", y_lim=[-3500,-200])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green", )
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red", )
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan", )
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet", )
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange", )
#axes[ax_index].set_title(env1+"_"+env2)
heuristic3 = heuristicsss[f"{env1}_{env2}"]

print(heuristic1, heuristic2, heuristic3)
axes[0].axhline(heuristic1, color="brown", linestyle="--", lw=5, label="Heuristic")
axes[1].axhline(heuristic2, color="brown", linestyle="--",  lw=5, label="Heuristic")
axes[2].axhline(heuristic3, color="brown", linestyle="--", lw=5, label="Heuristic")



for ax in axes:
    ax.grid()
plt.rc('font', size=80)
axes[1].set_xlabel('Timesteps ('+r'$\times \mathregular{10^{6}}$' + ')', fontsize=80)

plt.plot()
plt.savefig(f"sacred_scripts/plots/all_50_{cc_str}.pdf", bbox_inches='tight')
print("")

# %%
plt.style.use('seaborn-white')
fig, axes = plt.subplots(1,3)
fig.set_figheight(20)
fig.set_figwidth(120)
plt.subplots_adjust(wspace=0.17)

env1= "uc"
env2 = "100"
ax_index=0
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"  , y_lim=[-2500,-150])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic1= heuristicsss[f"{env1}_{env2}"]

env1= "c"
env2 = "100"
ax_index=1
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue"  , y_lim=[-2500,-150])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green")
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red")
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan")
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet")
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange")
#axes[ax_index].set_title(env1+"_"+env2)
heuristic2 = heuristicsss[f"{env1}_{env2}"]

env1= "owf"
env2 = "50"
ax_index=2
plot_function(results[f"qmix_{env1}_{env2}_{cc_str}"], name="qmix",      ax=axes[ax_index], color="blue" , y_lim=[-8000,-700])
plot_function(results[f"qvmix_{env1}_{env2}_{cc_str}"], name="qvmix",    ax=axes[ax_index], color="green", )
plot_function(results[f"qplex_{env1}_{env2}_{cc_str}"], name="qplex",    ax=axes[ax_index], color="red", )
plot_function(results[f"coma_{env1}_{env2}_{cc_str}"], name="coma",      ax=axes[ax_index], color="cyan", )
plot_function(results[f"facmac_{env1}_{env2}_{cc_str}"], name="facmac",  ax=axes[ax_index], color="violet", )
plot_function(results[f"iql_{env1}_{env2}_{cc_str}"], name="iql",        ax=axes[ax_index], color="orange", )
#axes[ax_index].set_title(env1+"_"+env2)
heuristic3 = heuristicsss[f"{env1}_{env2}"]

print(heuristic1, heuristic2, heuristic3)
axes[0].axhline(heuristic1, color="brown", linestyle="--", lw=5, label="Heuristic")
axes[1].axhline(heuristic2, color="brown", linestyle="--",  lw=5, label="Heuristic")
axes[2].axhline(heuristic3, color="brown", linestyle="--", lw=5, label="Heuristic")


for ax in axes:
    ax.grid()
plt.rc('font', size=80)
axes[1].set_xlabel('Timesteps ('+r'$\times \mathregular{10^{6}}$' + ')', fontsize=80)

plt.plot()
plt.savefig(f"sacred_scripts/plots/all_100_{cc_str}.pdf", bbox_inches='tight')
print("")
